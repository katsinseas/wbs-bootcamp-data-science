# %% [markdown]
# # Pandas challenges

# %% [markdown]
# Read the `vehicles.csv` dataframe and store it in a variable called `cars`:

# %%
import os 
os.getcwd()
# Out:
# '/Users/katiamarinelli/wbs-bootcamp-data-science/pandas-platform-files'

# %%
import pandas as pd
cars = pd.read_csv('https://raw.githubusercontent.com/katsinseas/wbs-bootcamp-data-science/main/pandas-platform-files/vehicles.csv')
cars
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# Explore the dataset:
#
# - How many rows and columns are there?
#
# - What are the data types of the columns?
#
# - Are there missing values?
#
# - What are the ranges / distributions of the numerical columns?
#
# - What are the value counts for the categorical columns?

# %%
# code here
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
#  14  Fuel Cost/Year           35952 non-null  int64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 4.1+ MB

# %%
print(cars.columns)
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %% [markdown]
# > 15 columns and 35952 columns

# %%
cars.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# min        6.000000      9.000000      7.000000                37.000000
# 25%       15.000000     20.000000     16.000000               395.000000
# 50%       17.000000     24.000000     19.000000               467.736842
# 75%       20.000000     27.000000     23.000000               555.437500
# max       58.000000     61.000000     56.000000              1269.571429
#
#        Fuel Cost/Year
# count    35952.000000
# mean      1892.598465
# std        506.958627
# min        600.000000
# 25%       1500.000000
# 50%       1850.000000
# 75%       2200.000000
# max       5800.000000

# %%
cars['Vehicle Class'].value_counts()
# Out:
# Compact Cars                          5185
# Subcompact Cars                       4374
# Midsize Cars                          4063
# Standard Pickup Trucks                2311
# Sport Utility Vehicle - 4WD           2081
# Two Seaters                           1784
# Large Cars                            1742
# Sport Utility Vehicle - 2WD           1615
# Special Purpose Vehicles              1404
# Small Station Wagons                  1371
# Minicompact Cars                      1212
# Standard Pickup Trucks 2WD            1141
# Vans                                  1121
# Standard Pickup Trucks 4WD             959
# Midsize-Large Station Wagons           633
# Special Purpose Vehicle 2WD            581
# Small Pickup Trucks                    524
# Small Sport Utility Vehicle 4WD        494
# Vans, Cargo Type                       432
# Midsize Station Wagons                 416
# Standard Sport Utility Vehicle 4WD     409
# Small Pickup Trucks 2WD                401
# Small Sport Utility Vehicle 2WD        374
# Minivan - 2WD                          331
# Vans, Passenger Type                   301
# Special Purpose Vehicle 4WD            256
# Small Pickup Trucks 4WD                200
# Standard Sport Utility Vehicle 2WD     179
# Minivan - 4WD                           47
# Standard Pickup Trucks/2wd               4
# Vans Passenger                           2
# Special Purpose Vehicles/2wd             2
# Special Purpose Vehicles/4wd             2
# Special Purpose Vehicle                  1
# Name: Vehicle Class, dtype: int64

# %%
cars.value_counts()
# Out:
# Make           Model               Year  Engine Displacement  Cylinders  Transmission     Drivetrain                  Vehicle Class                Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# smart          fortwo coupe        2016  0.9                  3.0        Manual 5-spd     Rear-Wheel Drive            Two Seaters                  Premium    9.417429           32        39           35            255.000000               1150              1
# Ford           E250 Econoline 2WD  1998  4.2                  6.0        Automatic 4-spd  Rear-Wheel Drive            Vans, Cargo Type             Regular    21.974000          13        17           15            592.466667               2200              1
#                                    2001  4.2                  6.0        Automatic 4-spd  Rear-Wheel Drive            Vans, Cargo Type             Regular    23.543571          13        18           14            634.785714               2400              1
#                                    2000  5.4                  8.0        Automatic 4-spd  Rear-Wheel Drive            Vans, Cargo Type             Regular    25.354615          12        17           13            683.615385               2550              1
#                                          4.2                  6.0        Automatic 4-spd  Rear-Wheel Drive            Vans, Cargo Type             Regular    23.543571          12        16           14            634.785714               2400              1
#                                                                                                                                                                                                                                                                 ..
# Mercedes-Benz  E500                2005  5.0                  8.0        Automatic 7-spd  Rear-Wheel Drive            Midsize Cars                 Premium    18.311667          15        23           18            493.722222               2250              1
#                                    2006  5.0                  8.0        Automatic 7-spd  Rear-Wheel Drive            Midsize Cars                 Premium    18.311667          15        23           18            493.722222               2250              1
#                E500 (Wagon)        2004  5.0                  8.0        Automatic 7-spd  Rear-Wheel Drive            Midsize Station Wagons       Premium    19.388824          14        22           17            522.764706               2400              1
#                E500 4matic         2004  5.0                  8.0        Automatic 5-spd  4-Wheel or All-Wheel Drive  Midsize Cars                 Premium    20.600625          14        19           16            555.437500               2550              1
# AM General     DJ Po Vehicle 2WD   1984  2.5                  4.0        Automatic 3-spd  2-Wheel Drive               Special Purpose Vehicle 2WD  Regular    19.388824          18        17           17            522.764706               1950              1
# Length: 35952, dtype: int64

# %% [markdown]
# Drop the column "Combined MPG"

# %%
# code here
cars_drop = cars.drop(columns=['Combined MPG'])
cars_drop.head(3)
# Out:
#          Make                Model  Year  Engine Displacement  Cylinders  \
# 0  AM General    DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General     FJ8c Post Office  1984                  4.2        6.0
# 2  AM General  Post Office DJ5 2WD  1985                  2.5        4.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  CO2 Emission Grams/Mile  \
# 0          19.388824        18           17               522.764706
# 1          25.354615        13           13               683.615385
# 2          20.600625        16           17               555.437500
#
#    Fuel Cost/Year
# 0            1950
# 1            2550
# 2            2100

# %% [markdown]
# Change column names so that there are no names with spaces or weird special characters:

# %%
# code here
cars_drop.apply()

# %% [markdown]
# What brand has the most cars?

# %%
cars_brand = cars['Make'].value_counts()
cars_brand.head(50)
# Out:
# Chevrolet            3643
# Ford                 2946
# Dodge                2360
# GMC                  2347
# Toyota               1836
# BMW                  1677
# Mercedes-Benz        1284
# Nissan               1253
# Volkswagen           1047
# Mitsubishi            950
# Mazda                 915
# Audi                  890
# Porsche               862
# Honda                 836
# Jeep                  829
# Pontiac               784
# Subaru                781
# Volvo                 717
# Hyundai               662
# Chrysler              641
# Buick                 537
# Mercury               532
# Suzuki                512
# Cadillac              508
# Kia                   493
# Plymouth              456
# Saab                  410
# Isuzu                 409
# Lexus                 397
# Oldsmobile            376
# Infiniti              345
# Jaguar                343
# MINI                  320
# Acura                 302
# Saturn                278
# Lincoln               273
# Ferrari               208
# Rolls-Royce           160
# Eagle                 156
# Geo                   144
# Land Rover            142
# Aston Martin          133
# Bentley               116
# Maserati              111
# Lamborghini           104
# Scion                  83
# Peugeot                74
# Daewoo                 67
# Ram                    57
# Roush Performance      53
# Name: Make, dtype: int64

# %%
cars.groupby(['Make']).count()
# Out:
#                              Model  Year  Engine Displacement  Cylinders  \
# Make
# AM General                       4     4                    4          4
# ASC Incorporated                 1     1                    1          1
# Acura                          302   302                  302        302
# Alfa Romeo                      41    41                   41         41
# American Motors Corporation     22    22                   22         22
# ...                            ...   ...                  ...        ...
# Volkswagen                    1047  1047                 1047       1047
# Volvo                          717   717                  717        717
# Wallace Environmental           32    32                   32         32
# Yugo                             8     8                    8          8
# smart                           20    20                   20         20
#
#                              Transmission  Drivetrain  Vehicle Class  \
# Make
# AM General                              4           4              4
# ASC Incorporated                        1           1              1
# Acura                                 302         302            302
# Alfa Romeo                             41          41             41
# American Motors Corporation            22          22             22
# ...                                   ...         ...            ...
# Volkswagen                           1047        1047           1047
# Volvo                                 717         717            717
# Wallace Environmental                  32          32             32
# Yugo                                    8           8              8
# smart                                  20          20             20
#
#                              Fuel Type  Fuel Barrels/Year  City MPG  \
# Make
# AM General                           4                  4         4
# ASC Incorporated                     1                  1         1
# Acura                              302                302       302
# Alfa Romeo                          41                 41        41
# American Motors Corporation         22                 22        22
# ...                                ...                ...       ...
# Volkswagen                        1047               1047      1047
# Volvo                              717                717       717
# Wallace Environmental               32                 32        32
# Yugo                                 8                  8         8
# smart                               20                 20        20
#
#                              Highway MPG  Combined MPG  \
# Make
# AM General                             4             4
# ASC Incorporated                       1             1
# Acura                                302           302
# Alfa Romeo                            41            41
# American Motors Corporation           22            22
# ...                                  ...           ...
# Volkswagen                          1047          1047
# Volvo                                717           717
# Wallace Environmental                 32            32
# Yugo                                   8             8
# smart                                 20            20
#
#                              CO2 Emission Grams/Mile  Fuel Cost/Year
# Make
# AM General                                         4               4
# ASC Incorporated                                   1               1
# Acura                                            302             302
# Alfa Romeo                                        41              41
# American Motors Corporation                       22              22
# ...                                              ...             ...
# Volkswagen                                      1047            1047
# Volvo                                            717             717
# Wallace Environmental                             32              32
# Yugo                                               8               8
# smart                                             20              20
#
# [127 rows x 14 columns]

# %% [markdown]
# What brand has the worse CO2 Emissions on average?

# %%
# code here
min_co2 = cars['CO2 Emission Grams/Mile'].min()
print(min_co2)
max_co2 = cars['CO2 Emission Grams/Mile'].max()
print(max_co2)
# Out:
# 37.0
# 1269.5714285714287

# %% [markdown]
# Which brands are more environment friendly?

# %%
# code here

# %% [markdown]
# Create 4 groups (bins) of cars, by Year. We want to explore how cars have evolved decade by decade.

# %%
# code here

# %% [markdown]
# Did cars consume more gas in the eighties?

# %%
# code here

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission?

# %%
# code here
# in the next notebook, we will learn how we can clean the "Trans" column

# %% [markdown]
# Group cars by fuel type and aggregate them by the following criteria:
#
# - The maximum number cylinders
# - The oldest year
# - The average Miles Per Gallon in the city

# %%
# code here

# %% [markdown]
# We want to use "Drivetrain" in a statistical model. Convert the column to numeric.

# %%
# code here

# %% [markdown]
# Read the `car_brands.csv` data:

# %%
# code here
df = pd.read_csv('car_brands.csv')
df
# Out:
#                            brand  revenue  production
# 0                     AM General     1537    1.002916
# 1               ASC Incorporated      232    1.628105
# 2                          Acura      234    3.394481
# 3                     Alfa Romeo     1174    2.313726
# 4    American Motors Corporation     1230    1.231024
# ..                           ...      ...         ...
# 122                   Volkswagen      273    1.033316
# 123                        Volvo     1312    0.057454
# 124        Wallace Environmental      277    5.744609
# 125                         Yugo      508    0.520953
# 126                        smart      447    2.229253
#
# [127 rows x 3 columns]

# %%
df.brand
# Out:
# 0                       AM General
# 1                 ASC Incorporated
# 2                            Acura
# 3                       Alfa Romeo
# 4      American Motors Corporation
#                   ...
# 122                     Volkswagen
# 123                          Volvo
# 124          Wallace Environmental
# 125                           Yugo
# 126                          smart
# Name: brand, Length: 127, dtype: object

# %% [markdown]
# Join the cars dataframe with the car brands dataframe.

# %%
# code here
joint_data = cars.join(df.set_index('brand'), on='Make')
joint_data
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  \
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
#        revenue  production
# 0         1537    1.002916
# 1         1537    1.002916
# 2         1537    1.002916
# 3         1537    1.002916
# 4          232    1.628105
# ...        ...         ...
# 35947      447    2.229253
# 35948      447    2.229253
# 35949      447    2.229253
# 35950      447    2.229253
# 35951      447    2.229253
#
# [35952 rows x 17 columns]

# %% [markdown]
# Which brands have the most revenue?

# %%
# code here

joint_data.sort_values('revenue', ascending=False)

#df.sort_values('revenue', ascending=False)
# Out:
#        Make                    Model  Year  Engine Displacement  Cylinders  \
# 16853   Geo  Tracker Convertible 4WD  1990                  1.6        4.0
# 16871   Geo          Tracker Van 2WD  1996                  1.6        4.0
# 16855   Geo  Tracker Convertible 4WD  1991                  1.6        4.0
# 16856   Geo  Tracker Convertible 4WD  1991                  1.6        4.0
# 16857   Geo  Tracker Convertible 4WD  1992                  1.6        4.0
# ...     ...                      ...   ...                  ...        ...
# 801    Audi               A4 quattro  2001                  2.8        6.0
# 800    Audi               A4 quattro  2001                  2.8        6.0
# 799    Audi               A4 quattro  2001                  1.8        4.0
# 798    Audi               A4 quattro  2001                  1.8        4.0
# 1111   Audi                       Q7  2007                  4.2        8.0
#
#           Transmission                  Drivetrain  \
# 16853  Automatic 3-spd  4-Wheel or All-Wheel Drive
# 16871     Manual 5-spd            Rear-Wheel Drive
# 16855  Automatic 3-spd  4-Wheel or All-Wheel Drive
# 16856     Manual 5-spd  4-Wheel or All-Wheel Drive
# 16857  Automatic 3-spd  4-Wheel or All-Wheel Drive
# ...                ...                         ...
# 801     Automatic (S5)  4-Wheel or All-Wheel Drive
# 800       Manual 5-spd  4-Wheel or All-Wheel Drive
# 799     Automatic (S5)  4-Wheel or All-Wheel Drive
# 798       Manual 5-spd  4-Wheel or All-Wheel Drive
# 1111    Automatic (S6)  4-Wheel or All-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 16853     Special Purpose Vehicles   Regular          14.982273        21
# 16871     Special Purpose Vehicles   Regular          14.982273        21
# 16855     Special Purpose Vehicles   Regular          15.695714        20
# 16856     Special Purpose Vehicles   Regular          14.330870        22
# 16857     Special Purpose Vehicles   Regular          15.695714        20
# ...                            ...       ...                ...       ...
# 801                   Compact Cars   Premium          18.311667        16
# 800                   Compact Cars   Premium          17.347895        16
# 799                   Compact Cars   Premium          16.480500        18
# 798                   Compact Cars   Premium          14.982273        19
# 1111   Sport Utility Vehicle - 4WD   Premium          23.543571        12
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  \
# 16853           23            22               403.954545            1500
# 16871           24            22               403.954545            1500
# 16855           22            21               423.190476            1600
# 16856           24            23               386.391304            1450
# 16857           22            21               423.190476            1600
# ...            ...           ...                      ...             ...
# 801             23            18               493.722222            2250
# 800             22            19               467.736842            2150
# 799             25            20               444.350000            2000
# 798             27            22               403.954545            1850
# 1111            17            14               634.785714            2900
#
#        revenue  production
# 16853     1988    1.100770
# 16871     1988    1.100770
# 16855     1988    1.100770
# 16856     1988    1.100770
# 16857     1988    1.100770
# ...        ...         ...
# 801         18    0.814725
# 800         18    0.814725
# 799         18    0.814725
# 798         18    0.814725
# 1111        18    0.814725
#
# [35952 rows x 17 columns]
